# %% [markdown]
# ## Creation Data Frame and Exploring data

# %%
import pandas as pd

# %% [markdown]
# ### Data frame

# %%
student={
    'id':['S2601','S2602','S2603','S2604'],
    'name':['safa','poojashree','rakshitha','rajiya'],
    'age':[19,20,17,21]

}
#Creation of data frame
df=pd.DataFrame(student)
df

# %%
# #Shape
df.shape
# #size
df.size
# #column
df.columns
#rename
df.rename(columns={"id":"student_id"})
#permanent rename
df.rename(columns={"id":"student_id"},inplace=True)

# %% [markdown]
# ### Export to csv file

# %%
df.to_csv("student_data.csv")
df.to_csv("student2_data.csv",index=False)

# %% [markdown]
# ### Import data

# %%
#import from csv file
#same folder
df=pd.read_csv("companydemo.csv")
#diff folder
df1=pd.read_csv("C:/Users/HP/OneDrive/Desktop/placement/pandas/subdata_pandas/student.csv")
df1

# %%
#import from excel file
df2=pd.read_excel("C:/Users/HP/OneDrive/Desktop/placement/pandas/subdata_pandas/expense.xlsx")
df3=pd.read_excel("subdata_pandas/expense.xlsx")
df3

# %% [markdown]
# ### Exploring data

# %%
df=pd.read_csv("subdata_pandas/employee.csv")
df

# %%
#Top 10 rows
df.head(10)
#last 10 rows
df.tail(10)
#shape
df.shape
#size
df.size
#describe
df.describe()
#Info
df.info()
# Out:
#                id   education         salary  starting_salary    job_time  \
# count  474.000000  474.000000     474.000000       474.000000  474.000000
# mean   237.500000   14.609705   34419.567511     17016.086498    6.759072
# std    136.976275    2.442919   17075.661465      7870.638154    0.838523
# min      1.000000   12.000000   15750.000000      9000.000000    5.250000
# 25%    119.250000   12.000000   24000.000000     12487.500000    6.000000
# 50%    237.500000   15.000000   28875.000000     15000.000000    6.750000
# 75%    355.750000   16.000000   36937.500000     17490.000000    7.500000
# max    474.000000   21.000000  135000.000000     79980.000000    8.170000
#
#        previous_experience
# count           449.000000
# mean              8.406682
# std               8.750270
# min               0.170000
# 25%               2.000000
# 50%               4.920000
# 75%              12.000000
# max              39.670000
